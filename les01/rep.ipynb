# %% [markdown]
# <a href="https://colab.research.google.com/github/ramvrum/dap-2024/blob/main/les01/rep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Отчет по лабораторной работе №1
# ### Цель: подготовить среду для анализа данных
# **Ход работы.**
#
# 1.   Создана учетная запись в сервисе GitHub
# 2.   Выполнен форк [репозитория](https://github.com/Nikita-Puzyrev/dap-2024.git)
# 3.   Создана учетная запись в [Google Colab](https://colab.research.google.com)
# 4.   Настроена интеграция Google Colab и GitHub
# 5.   Создан в Google Colab отчет о выполненой работе в виде файла rep.ipynb. Использована Markdown разметка
# 6. Отчет сохранен в репозиторий github в директории ./les01
# 7. Создан pull request в  [репозиторий](https://github.com/Nikita-Puzyrev/dap-2024.git).
#
# **Вывод**: среда для анализа данных подготовлена
